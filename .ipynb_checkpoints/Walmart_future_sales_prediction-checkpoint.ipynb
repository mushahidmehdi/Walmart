# %% [markdown]
# ##### Walmart sale force is kaggle challenge to learn Supervised learning to predict future probable outcome given the dataset. I will try to expalin all the twists and turns as simple and possible without hanging on too much on the details.

# %% [markdown]
# First of all, let's explore what data we have and what features and available in our data that can be useful.
# Well, the Data is split in four csvs and two of them is train & test dataset while the others are features & store-info.

# %%
# Lets import change the cvs dataset into pandas dataframe.
# In this tutorial I will import toolkits and Libraries along the way as soon as we start using them.

import pandas as pd

features=pd.read_csv('/home/musho/Desktop/Walmart_data/features.csv')
storesdata=pd.read_csv('/home/musho/Desktop/Walmart_data/stores.csv')
train=pd.read_csv('/home/musho/Desktop/Walmart_data/train.csv')
test=pd.read_csv('/home/musho/Desktop/Walmart_data/test.csv')

# %%
# Let's explore the features data. This dataset have 8189 rows and if we analyze carefully the date ranges for 
# 2010-02-05 to 2013-07-26 which is 182 weeks also there are 45 stores in the data which mathmatically make 8189.

features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
# Now, if we look at training data it contains 421569 weeky_sales, which doesn't make any sense because there are
# only 8189 stores are given, but if we analyze carefully in training data number of department per store also 
# has been given, therefore, if we consider departmental level weeky sales the number 421k of sales make sense.

train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
# This dataset is same as training data set but only difference is it doen't contains weekly_sales report,

test.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
# store data

storesdata.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
# First thing we will do is to merge all the data into single dataframe, we can get over all map of the data.
# We will use merge method due to its flexiblity.
# We will label both train test set with its respective name with a new column, this will help us to split the data
# once we had competly engineered useful features..

feat_stor_df = pd.merge(features, storesdata, on=['Store'], how='inner')

Train_df = pd.merge(feat_stor_df, train, on=['Store', 'Date', 'IsHoliday'], how='inner')

Test_df = pd.merge(feat_stor_df, test, on=['Store', 'Date', 'IsHoliday'], how='inner')

Train_df['Split'] = 'Train'

Test_df['Split'] = 'Test'

dataframe = pd.concat([Train_df, Test_df], axis=0)

# %%
# Now let look at the dataframe and what we have
dataframe.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-05        42.31       2.572        NaN        NaN
# 2      1  2010-02-05        42.31       2.572        NaN        NaN
# 3      1  2010-02-05        42.31       2.572        NaN        NaN
# 4      1  2010-02-05        42.31       2.572        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106      False    A
# 1        NaN        NaN        NaN  211.096358         8.106      False    A
# 2        NaN        NaN        NaN  211.096358         8.106      False    A
# 3        NaN        NaN        NaN  211.096358         8.106      False    A
# 4        NaN        NaN        NaN  211.096358         8.106      False    A
#
#      Size  Dept  Weekly_Sales  Split
# 0  151315     1      24924.50  Train
# 1  151315     2      50605.27  Train
# 2  151315     3      13740.12  Train
# 3  151315     4      39954.04  Train
# 4  151315     5      32229.38  Train

# %%
# Let's check what kind of numerical relationship in our Measure of Center and Measuare of speard in the numerical 
# data.

dataframe.describe()
# Out:
#                Store    Temperature     Fuel_Price      MarkDown1  \
# count  536634.000000  536634.000000  536634.000000  265596.000000
# mean       22.208621      58.771762       3.408310    7438.004144
# std        12.790580      18.678716       0.430861    9411.341379
# min         1.000000      -7.290000       2.472000   -2781.450000
# 25%        11.000000      45.250000       3.041000    2114.640000
# 50%        22.000000      60.060000       3.523000    5126.540000
# 75%        33.000000      73.230000       3.744000    9303.850000
# max        45.000000     101.950000       4.468000  103184.980000
#
#            MarkDown2      MarkDown3      MarkDown4      MarkDown5  \
# count  197685.000000  242326.000000  237143.000000  266496.000000
# mean     3509.274827    1857.913525    3371.556866    4324.021158
# std      8992.047197   11616.143274    6872.281734   13549.262124
# min      -265.760000    -179.260000       0.220000    -185.170000
# 25%        72.500000       7.220000     336.240000    1570.112500
# 50%       385.310000      40.760000    1239.040000    2870.910000
# 75%      2392.390000     174.260000    3397.080000    5012.220000
# max    104519.540000  149483.310000   67474.850000  771448.100000
#
#                  CPI   Unemployment           Size           Dept  \
# count  498472.000000  498472.000000  536634.000000  536634.000000
# mean      172.090481       7.791888  136678.550960      44.277301
# std        39.542149       1.865076   61007.711799      30.527358
# min       126.064000       3.684000   34875.000000       1.000000
# 25%       132.521867       6.623000   93638.000000      18.000000
# 50%       182.442420       7.795000  140167.000000      37.000000
# 75%       213.748126       8.549000  202505.000000      74.000000
# max       228.976456      14.313000  219622.000000      99.000000
#
#         Weekly_Sales
# count  421570.000000
# mean    15981.258123
# std     22711.183519
# min     -4988.940000
# 25%      2079.650000
# 50%      7612.030000
# 75%     20205.852500
# max    693099.360000

# %% [markdown]
# Now, let's try understand what kind of hidden relations underlaying in our dataset. I will use correation
# for data visualiztion, although, it doesn’t cover all the nuance, it can be a very handy guide for visual
# learners.

# %%
# Now both compute the correlation matrix

corr = dataframe.corr()
corr
# Out:
#                  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Store         1.000000    -0.048379    0.073123  -0.104831  -0.037433
# Temperature  -0.048379     1.000000    0.099235  -0.107973  -0.323246
# Fuel_Price    0.073123     0.099235    1.000000   0.065501  -0.200338
# MarkDown1    -0.104831    -0.107973    0.065501   1.000000   0.014288
# MarkDown2    -0.037433    -0.323246   -0.200338   0.014288   1.000000
# MarkDown3    -0.028302    -0.076256   -0.059407  -0.096141  -0.055310
# MarkDown4    -0.000270    -0.060487   -0.010329   0.810074  -0.048790
# MarkDown5    -0.000199     0.002354   -0.023529   0.078151  -0.010670
# CPI          -0.211333     0.169070   -0.180445  -0.041049  -0.043525
# Unemployment  0.208847     0.145725   -0.030976   0.025099  -0.002587
# IsHoliday    -0.000671    -0.163056   -0.077976   0.155907   0.306810
# Size         -0.183736    -0.058202    0.009058   0.325043   0.128038
# Dept          0.023061     0.004151    0.003273  -0.002414   0.000646
# Weekly_Sales -0.085195    -0.002312   -0.000120   0.085251   0.024130
#
#               MarkDown3  MarkDown4  MarkDown5       CPI  Unemployment  \
# Store         -0.028302  -0.000270  -0.000199 -0.211333      0.208847
# Temperature   -0.076256  -0.060487   0.002354  0.169070      0.145725
# Fuel_Price    -0.059407  -0.010329  -0.023529 -0.180445     -0.030976
# MarkDown1     -0.096141   0.810074   0.078151 -0.041049      0.025099
# MarkDown2     -0.055310  -0.048790  -0.010670 -0.043525     -0.002587
# MarkDown3      1.000000  -0.064432  -0.017531 -0.020147     -0.002328
# MarkDown4     -0.064432   1.000000   0.040804 -0.051643      0.021755
# MarkDown5     -0.017531   0.040804   1.000000  0.002009      0.034047
# CPI           -0.020147  -0.051643   0.002009  1.000000     -0.301696
# Unemployment  -0.002328   0.021755   0.034047 -0.301696      1.000000
# IsHoliday      0.455563   0.137478  -0.025361  0.001410     -0.002996
# Size           0.049204   0.161441   0.140382 -0.003341     -0.057509
# Dept           0.000856   0.003413   0.000559 -0.007262      0.007077
# Weekly_Sales   0.060385   0.045414   0.090362 -0.020921     -0.025864
#
#               IsHoliday      Size      Dept  Weekly_Sales
# Store         -0.000671 -0.183736  0.023061     -0.085195
# Temperature   -0.163056 -0.058202  0.004151     -0.002312
# Fuel_Price    -0.077976  0.009058  0.003273     -0.000120
# MarkDown1      0.155907  0.325043 -0.002414      0.085251
# MarkDown2      0.306810  0.128038  0.000646      0.024130
# MarkDown3      0.455563  0.049204  0.000856      0.060385
# MarkDown4      0.137478  0.161441  0.003413      0.045414
# MarkDown5     -0.025361  0.140382  0.000559      0.090362
# CPI            0.001410 -0.003341 -0.007262     -0.020921
# Unemployment  -0.002996 -0.057509  0.007077     -0.025864
# IsHoliday      1.000000  0.000345  0.001002      0.012774
# Size           0.000345  1.000000 -0.002004      0.243828
# Dept           0.001002 -0.002004  1.000000      0.148032
# Weekly_Sales   0.012774  0.243828  0.148032      1.000000

# %% [markdown]
# If you had observed, the upper half of the triangle is exactly symetrical to the lower half of the triangle.
# We will mask the upper half, therefore.

# %%
# Convert all the relationship to boolen by using zeros_like method True.

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Now mask symetrical upper half of the correlation because it is just a repetation. 

mask = np.zeros_like(corr, dtype=np.bool)

mask[np.triu_indices_from(mask)] = True

corr = dataframe.corr()

sns.set(style='white')

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 10))

cmap = sns.diverging_palette(220, 20, as_cmap=True)


sns.heatmap(corr, mask=mask, square=True, center=0, vmax=0.3, linewidths=0.5, cmap=cmap, cbar_kws={'shrink':0.5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Let's explore the hidden relations in the heatmap.
#
#  1- Greater size store genrate greater sales, as expected.
#
#  2- It appears that higher department numbers have higher sales.
#
#  3- Unemployment causes very slight inverse effect on sales. Unfortunatly, there are no other more useful insight in
#  the map base on weekly sales

# %%
# Like every machine learning data we have to hunt down any missing values in our dataset. Otherwise,
# our model will not be able predict on out of sample data.

dataframe.isnull().sum()
# Out:
# Store                0
# Date                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       271038
# MarkDown2       338949
# MarkDown3       294308
# MarkDown4       299491
# MarkDown5       270138
# CPI              38162
# Unemployment     38162
# IsHoliday            0
# Type                 0
# Size                 0
# Dept                 0
# Weekly_Sales    115064
# Split                0
# dtype: int64

# %% [markdown]
# It appears that there are few columns where data is missing. For weekly sales column it should be as we have to
# predict for the testing set, but for the rest of column we will do some basic feature engineering by twisting and turning the knobs and dials up and down in order to make our data feedable to our model.
# Firstly, we will add few new columns by extracting the given values available in the columns where some
# values are missing.

# %%
# Filter all the non-nan values from the missing column and assign new series with filter values as boolen

dataframe = dataframe.assign(mk1 = dataframe['MarkDown1'].notna())
dataframe = dataframe.assign(mk2 = dataframe['MarkDown2'].notna())
dataframe = dataframe.assign(mk3 = dataframe['MarkDown3'].notna())
dataframe = dataframe.assign(mk4 = dataframe['MarkDown4'].notna())
dataframe = dataframe.assign(mk5 = dataframe.MarkDown5.notna())
dataframe = dataframe.assign(mcpi = dataframe.CPI.notna())
dataframe = dataframe.assign(mUemp = dataframe.Unemployment.notna())

# %%
# Now we will fill all the missing values with 0 

pd.set_option('display.max_columns', None)
dataframe.fillna(0, inplace=True)
dataframe.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        0.0        0.0
# 1      1  2010-02-05        42.31       2.572        0.0        0.0
# 2      1  2010-02-05        42.31       2.572        0.0        0.0
# 3      1  2010-02-05        42.31       2.572        0.0        0.0
# 4      1  2010-02-05        42.31       2.572        0.0        0.0
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        0.0        0.0        0.0  211.096358         8.106      False    A
# 1        0.0        0.0        0.0  211.096358         8.106      False    A
# 2        0.0        0.0        0.0  211.096358         8.106      False    A
# 3        0.0        0.0        0.0  211.096358         8.106      False    A
# 4        0.0        0.0        0.0  211.096358         8.106      False    A
#
#      Size  Dept  Weekly_Sales  Split    mk1    mk2    mk3    mk4    mk5  mcpi  \
# 0  151315     1      24924.50  Train  False  False  False  False  False  True
# 1  151315     2      50605.27  Train  False  False  False  False  False  True
# 2  151315     3      13740.12  Train  False  False  False  False  False  True
# 3  151315     4      39954.04  Train  False  False  False  False  False  True
# 4  151315     5      32229.38  Train  False  False  False  False  False  True
#
#    mUemp
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True

# %%
# Let's change the date format we will use datetime.strptime() method by mapping through all the dates in series,
# changing them into a string and appending then into a list, eventually into datetime format.

from datetime import datetime
from datetime import timedelta

dataframe['DateType'] = [datetime.strptime(date, '%Y-%m-%d') for date in dataframe['Date']
                         .astype(str).values.tolist()]

dataframe['Month']= [date.month for date in dataframe['DateType']]

# %% [markdown]
# To gain futher insight of our data we will filter down our dataset where we have higher amount sales. To know,
# the relation of higher sales per week, we have to map down our dataset where weekly_sales are higher and try to
# compare it with the possible cause through given features.

# %%
# Firstly, lets find the weeks where we have sales above higher 300k.

dataframe.loc[dataframe['Weekly_Sales'] > 300000].head(50)
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 32594       4  2010-11-26        48.08       2.752       0.00       0.00
# 36312       4  2011-11-25        47.96       3.225     561.45     137.88
# 36557       4  2011-12-23        35.92       3.103    2461.94      69.05
# 51826       6  2010-11-26        65.79       2.735       0.00       0.00
# 55545       6  2011-11-25        62.78       3.236     429.03     171.88
# 90645      10  2010-11-26        55.33       3.162       0.00       0.00
# 90886      10  2010-12-24        57.06       3.236       0.00       0.00
# 90936      10  2010-12-24        57.06       3.236       0.00       0.00
# 94393      10  2011-11-25        60.68       3.760     174.72     329.00
# 94634      10  2011-12-23        48.36       3.541     300.02      77.73
# 110792     12  2010-11-26        47.66       3.162       0.00       0.00
# 114299     12  2011-11-25        53.25       3.622    5391.83       8.00
# 131088     14  2010-11-26        46.15       3.039       0.00       0.00
# 131321     14  2010-12-24        30.59       3.141       0.00       0.00
# 131368     14  2010-12-24        30.59       3.141       0.00       0.00
# 134722     14  2011-11-25        48.71       3.492     286.52      54.00
# 170247     18  2010-11-26        40.81       3.070       0.00       0.00
# 173813     18  2011-11-25        41.97       3.536     748.82      46.00
# 180227     19  2010-11-26        42.62       3.186       0.00       0.00
# 190370     20  2010-11-26        46.66       3.039       0.00       0.00
# 190660     20  2010-12-24        25.17       3.141       0.00       0.00
# 194093     20  2011-11-25        46.38       3.492     335.66      80.00
# 210037     22  2010-11-26        44.61       3.070       0.00       0.00
# 213530     22  2011-11-25        46.28       3.536    1649.31       0.00
# 219800     23  2010-11-26        34.95       3.070       0.00       0.00
# 223478     23  2011-11-25        35.23       3.536      70.24      47.47
# 259799     27  2010-11-26        46.67       3.186       0.00       0.00
# 263519     27  2011-11-25        47.88       3.689     164.01      27.47
# 269997     28  2010-11-26        47.66       3.162       0.00       0.00
# 273668     28  2011-11-25        53.25       3.622    2232.08     179.73
# 333594     35  2010-11-26        46.67       3.039       0.00       0.00
# 337053     35  2011-11-25        47.88       3.492    1333.24       0.00
# 364033     39  2010-11-26        67.75       2.735       0.00       0.00
# 367624     39  2011-11-25        66.36       3.236     224.08     292.94
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 32594        0.00       0.00       0.00  126.669267         7.127       True
# 36312    83340.33      44.04    9239.23  129.836400         5.143       True
# 36557     2938.24      52.00    4396.76  129.984548         5.143      False
# 51826        0.00       0.00       0.00  213.267296         7.007       True
# 55545    83192.81      15.00     986.23  220.041741         6.551       True
# 90645        0.00       0.00       0.00  126.669267         9.003       True
# 90886        0.00       0.00       0.00  126.983581         9.003      False
# 90936        0.00       0.00       0.00  126.983581         9.003      False
# 94393   141630.61      79.00    1009.98  129.836400         7.874       True
# 94634     2432.01     108.37    4078.21  129.984548         7.874      False
# 110792       0.00       0.00       0.00  126.669267        14.313       True
# 114299   63143.29      49.27    2115.67  129.836400        12.890       True
# 131088       0.00       0.00       0.00  182.783277         8.724       True
# 131321       0.00       0.00       0.00  182.544590         8.724      False
# 131368       0.00       0.00       0.00  182.544590         8.724      False
# 134722   89402.64      13.00    1915.80  188.350400         8.523       True
# 170247       0.00       0.00       0.00  132.836933         9.331       True
# 173813   71366.86      19.00     577.40  136.478800         8.471       True
# 180227       0.00       0.00       0.00  132.836933         8.067       True
# 190370       0.00       0.00       0.00  204.962100         7.484       True
# 190660       0.00       0.00       0.00  204.637673         7.484      False
# 194093  101378.79      64.46    2251.98  211.412076         7.082       True
# 210037       0.00       0.00       0.00  136.689571         8.572       True
# 213530   70087.94       7.50    5266.90  140.421786         7.706       True
# 219800       0.00       0.00       0.00  132.836933         5.287       True
# 223478  103991.94       7.00     677.31  136.478800         4.420       True
# 259799       0.00       0.00       0.00  136.689571         8.021       True
# 263519   73934.06      24.22     540.56  140.421786         7.906       True
# 269997       0.00       0.00       0.00  126.669267        14.313       True
# 273668   61319.72     513.76    1790.89  129.836400        12.890       True
# 333594       0.00       0.00       0.00  136.689571         8.763       True
# 337053   58563.24      20.97    6386.86  140.421786         8.745       True
# 364033       0.00       0.00       0.00  210.515277         8.476       True
# 367624   77126.16      77.74    4875.43  217.181253         7.716       True
#
#        Type    Size  Dept  Weekly_Sales  Split    mk1    mk2    mk3    mk4  \
# 32594     A  205863    72     381072.11  Train  False  False  False  False
# 36312     A  205863    72     385051.04  Train   True   True   True   True
# 36557     A  205863     7     318422.01  Train   True   True   True   True
# 51826     A  202505    72     342578.65  Train  False  False  False  False
# 55545     A  202505    72     326866.60  Train   True   True   True   True
# 90645     B  126512    72     693099.36  Train  False  False  False  False
# 90886     B  126512     7     406988.63  Train  False  False  False  False
# 90936     B  126512    72     404245.03  Train  False  False  False  False
# 94393     B  126512    72     630999.19  Train   True   True   True   True
# 94634     B  126512     7     341308.00  Train   True   True   True   True
# 110792    B  112238    72     359995.60  Train  False  False  False  False
# 114299    B  112238    72     360140.66  Train   True   True   True   True
# 131088    A  200898    72     474330.10  Train  False  False  False  False
# 131321    A  200898     7     356867.25  Train  False  False  False  False
# 131368    A  200898    72     313933.22  Train  False  False  False  False
# 134722    A  200898    72     375948.31  Train   True   True   True   True
# 170247    B  120653    72     353008.64  Train  False  False  False  False
# 173813    B  120653    72     305161.38  Train   True   True   True   True
# 180227    A  203819    72     339846.03  Train  False  False  False  False
# 190370    A  203742    72     422306.25  Train  False  False  False  False
# 190660    A  203742    72     303006.44  Train  False  False  False  False
# 194093    A  203742    72     392023.02  Train   True   True   True   True
# 210037    B  119557    72     393705.20  Train  False  False  False  False
# 213530    B  119557    72     345532.23  Train   True  False   True   True
# 219800    B  114533    72     369830.98  Train  False  False  False  False
# 223478    B  114533    72     347680.08  Train   True   True   True   True
# 259799    A  204184    72     420586.57  Train  False  False  False  False
# 263519    A  204184    72     368484.19  Train   True   True   True   True
# 269997    A  206302    72     355356.39  Train  False  False  False  False
# 273668    A  206302    72     351763.71  Train   True   True   True   True
# 333594    B  103681    72     627962.93  Train  False  False  False  False
# 337053    B  103681    72     649770.18  Train   True  False   True   True
# 364033    A  184109    72     339700.62  Train  False  False  False  False
# 367624    A  184109    72     351553.98  Train   True   True   True   True
#
#           mk5  mcpi  mUemp   DateType  Month
# 32594   False  True   True 2010-11-26     11
# 36312    True  True   True 2011-11-25     11
# 36557    True  True   True 2011-12-23     12
# 51826   False  True   True 2010-11-26     11
# 55545    True  True   True 2011-11-25     11
# 90645   False  True   True 2010-11-26     11
# 90886   False  True   True 2010-12-24     12
# 90936   False  True   True 2010-12-24     12
# 94393    True  True   True 2011-11-25     11
# 94634    True  True   True 2011-12-23     12
# 110792  False  True   True 2010-11-26     11
# 114299   True  True   True 2011-11-25     11
# 131088  False  True   True 2010-11-26     11
# 131321  False  True   True 2010-12-24     12
# 131368  False  True   True 2010-12-24     12
# 134722   True  True   True 2011-11-25     11
# 170247  False  True   True 2010-11-26     11
# 173813   True  True   True 2011-11-25     11
# 180227  False  True   True 2010-11-26     11
# 190370  False  True   True 2010-11-26     11
# 190660  False  True   True 2010-12-24     12
# 194093   True  True   True 2011-11-25     11
# 210037  False  True   True 2010-11-26     11
# 213530   True  True   True 2011-11-25     11
# 219800  False  True   True 2010-11-26     11
# 223478   True  True   True 2011-11-25     11
# 259799  False  True   True 2010-11-26     11
# 263519   True  True   True 2011-11-25     11
# 269997  False  True   True 2010-11-26     11
# 273668   True  True   True 2011-11-25     11
# 333594  False  True   True 2010-11-26     11
# 337053   True  True   True 2011-11-25     11
# 364033  False  True   True 2010-11-26     11
# 367624   True  True   True 2011-11-25     11

# %%
# There are 34 weeks where we have more than $300k sales. Interestly, it appears at the and of years November and 
# December are common. Well, we can easily infered that this sales skyrocket has been caused
# of back-friday and Chrismis. Remember, holidays usually have higher sales rate but these are the week-days.
# Let's add column for each PreChristmasDay and BlackFriday

dataframe['BlackFriday'] = np.where((dataframe.DateType == datetime(2010, 11, 26)) |
                                     (dataframe.DateType == datetime(2010, 11, 25)) |
                                     (dataframe.DateType == datetime(2011, 11, 25)) |
                                     (dataframe.DateType == datetime(2010, 11, 24)),
                                     'Yes', 'No' )

dataframe['PreChristmasDay'] = np.where((dataframe.DateType == datetime(2010, 12, 24)) |
                                     (dataframe.DateType == datetime(2011, 12, 23)),
                                     'Yes', 'No' )

# %%
# Now lets find the MedianSales add into the series, we will need it in next step too find sales in Prior Week.
# The Median sale will be based on the number of department per month for each type of stores. This 

medians = pd.DataFrame({'MedianSales': dataframe.loc[dataframe['Split'] == 'Train']
                      .groupby(by=['Type', 'Dept', 'Store', 'Month',
                      'IsHoliday'])['Weekly_Sales'].median()
                       }).reset_index()

# %%
# Merge the Median Sales with dataframe and fill any NaN value with median of train. 

dataframe = dataframe.merge(medians, how='outer', on=['Type', 'Dept', 'Store', 'Month', 'IsHoliday'])
dataframe['MedianSales'].fillna(dataframe['MedianSales'].loc[dataframe.Split == 'Train'].median(), inplace=True)


# We now add a week prior DateTime into the dataframe, this will allow to trace the sales each week in a month.

dataframe['PriorWeekDate'] = dataframe['DateType']-timedelta(7)

Sorted_df = dataframe.sort_values(['Store', 'Dept', 'DateType'], ascending=[1,1,1]).reset_index(drop=True)

# %%
# Now add sales for the week prior to our given dates, as there is no data aviable we will add NaN to the column.

Sorted_df['PriorWeekSale'] = np.nan
Sorted_df['PriorWeek'] = np.nan

# intialize last row for first iteration of dataframe. Doesn't really matter what it is
last = dataframe.loc[0]  
print(last)

# intialize last row for first iteration of sorted_df. Doesn't really matter what it is
row_len = Sorted_df.shape[0]
print(row_len)
for index, row in Sorted_df.iterrows():
    
    lag_date = row['PriorWeekDate']
    
    if ((last['DateType'] == lag_date) & (last['Weekly_Sales'] > 0)):
        Sorted_df.at[index, 'PriorWeekSale'] = last['Weekly_Sales']
        Sorted_df.at[index, "PriorWeek"] = 1
    else:
        Sorted_df.at[index, 'PriorWeekSale'] =  row['MedianSales']
        Sorted_df.at[index, "PriorWeek"] = 0
        
    last = row      # Remember value from last row and replace the dataframe.loc[0] with the a new value of
                    # last row & select next date for next itteration
    
    if(index%int(row_len/10)==0):
        print(str(int(index*100/row_len))+ '% loaded')
# Out:
# Store                                1
# Date                        2010-02-05
# Temperature                      42.31
# Fuel_Price                       2.572
# MarkDown1                            0
# MarkDown2                            0
# MarkDown3                            0
# MarkDown4                            0
# MarkDown5                            0
# CPI                            211.096
# Unemployment                     8.106
# IsHoliday                        False
# Type                                 A
# Size                            151315
# Dept                                 1
# Weekly_Sales                   24924.5
# Split                            Train
# mk1                              False
# mk2                              False
# mk3                              False
# mk4                              False
# mk5                              False
# mcpi                              True
# mUemp                             True
# DateType           2010-02-05 00:00:00
# Month                                2
# BlackFriday                         No
# PreChristmasDay                     No
# MedianSales                    23510.5
# PriorWeekDate      2010-01-29 00:00:00
# Name: 0, dtype: object
# 536634
# 0% loaded
# 9% loaded
# 19% loaded
# 29% loaded
# 39% loaded
# 49% loaded
# 59% loaded
# 69% loaded
# 79% loaded
# 89% loaded
# 99% loaded

# %%
Sorted_df[['Dept', 'Store', 'DateType', 'PriorWeekSale', 'Weekly_Sales', 'MedianSales']].head()
# Out:
#    Dept  Store   DateType  PriorWeekSale  Weekly_Sales  MedianSales
# 0     1      1 2010-02-05       23510.49      24924.50     23510.49
# 1     1      1 2010-02-12       24924.50      46039.49     37887.17
# 2     1      1 2010-02-19       46039.49      41595.55     23510.49
# 3     1      1 2010-02-26       41595.55      19403.54     23510.49
# 4     1      1 2010-03-05       19403.54      21827.90     21280.40

# %%
# Merge sorted_df with dataframe

dataframe = dataframe.merge(Sorted_df[['Dept', 'Store', 'DateType', 'PriorWeek', 'PriorWeekSale']],
                            how='inner', on=['Dept', 'Store', 'DateType'])

# %% [markdown]
# So far so good, the summary of what we have done are, we hunt-down for the null values, added columns by
# filtering values, and add 0 into the dataframe.Then we change Date into Datetime
# format by adding two more rows for DateType and for the Month, this allowed us to work with date related
# problems.Then we added two more series for Blackfriday and PreChrismis as there were extremly high
# weeky sale record found, and added the median price into the dataframe base on per month.

# %%
# As we have some unordered categorical data into our dataframe, therefore, now we add some dummy encoder aka
# indicator-variable into data for all the categorical columns which contains more sales relationship compared
# to other, before that,to indentify those columns and we will map the column title to each value in the series
# So summy encoder can easily be identify.

dataframe['IsHoliday'] = 'IsHoliday_'+dataframe['IsHoliday'].map(str)
dataframe['BlackFriday'] = "BlackFriday_"+dataframe['BlackFriday'].map(str)
dataframe['PreChristmasDay'] = "PreChristmasDay_"+dataframe['PreChristmasDay'].map(str)

IsHolidayDummy = pd.get_dummies(dataframe.IsHoliday)
PreChristmasDummy = pd.get_dummies(dataframe.PreChristmasDay)
BlackFridayDummy = pd.get_dummies(dataframe.BlackFriday)

dataframe = pd.concat([dataframe, IsHolidayDummy, PreChristmasDummy, BlackFridayDummy], axis=1)

# %%
# Let's find Sales difference from median to PreWeekSales. 

dataframe['SalesDifference'] = dataframe['MedianSales'] - dataframe['PriorWeekSale']

# %%
dataframe[['Dept', 'Store', 'DateType', 'PriorWeekSale', 'Weekly_Sales', 'MedianSales']].head()
# Out:
#    Dept  Store   DateType  PriorWeekSale  Weekly_Sales  MedianSales
# 0     1      1 2010-02-05       23510.49      24924.50     23510.49
# 1     1      1 2010-02-19       46039.49      41595.55     23510.49
# 2     1      1 2010-02-26       41595.55      19403.54     23510.49
# 3     1      1 2011-02-04       18461.18      21665.76     23510.49
# 4     1      1 2011-02-18       37887.17      46845.87     23510.49

# %%
dataframe['Difference'] = dataframe['MedianSales'] - dataframe['Weekly_Sales']

dataframe
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  2010-02-05        42.31       2.572       0.00        0.0
# 1           1  2010-02-19        39.93       2.514       0.00        0.0
# 2           1  2010-02-26        46.63       2.561       0.00        0.0
# 3           1  2011-02-04        42.27       2.989       0.00        0.0
# 4           1  2011-02-18        57.36       3.045       0.00        0.0
# ...       ...         ...          ...         ...        ...        ...
# 536629     44  2013-06-14        76.41       3.771     351.38        0.0
# 536630     44  2013-07-12        78.93       3.666     182.25        0.0
# 536631     44  2013-07-19        80.81       3.665     118.82        0.0
# 536632     44  2013-07-26        83.62       3.669     134.31        0.0
# 536633     45  2013-04-26        50.64       3.615    1260.65        0.0
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0            0.00       0.00       0.00  211.096358         8.106
# 1            0.00       0.00       0.00  211.289143         8.106
# 2            0.00       0.00       0.00  211.319643         8.106
# 3            0.00       0.00       0.00  212.566881         7.742
# 4            0.00       0.00       0.00  213.247885         7.742
# ...           ...        ...        ...         ...           ...
# 536629       4.89       6.35     867.28    0.000000         0.000
# 536630       6.63       0.00    1842.48    0.000000         0.000
# 536631       3.15       0.00     514.08    0.000000         0.000
# 536632       1.00       0.00     199.75    0.000000         0.000
# 536633      57.52      40.51    2476.18  193.589304         8.335
#
#               IsHoliday Type    Size  Dept  Weekly_Sales  Split    mk1    mk2  \
# 0       IsHoliday_False    A  151315     1      24924.50  Train  False  False
# 1       IsHoliday_False    A  151315     1      41595.55  Train  False  False
# 2       IsHoliday_False    A  151315     1      19403.54  Train  False  False
# 3       IsHoliday_False    A  151315     1      21665.76  Train  False  False
# 4       IsHoliday_False    A  151315     1      46845.87  Train  False  False
# ...                 ...  ...     ...   ...           ...    ...    ...    ...
# 536629  IsHoliday_False    C   39910    44          0.00   Test   True  False
# 536630  IsHoliday_False    C   39910    22          0.00   Test   True  False
# 536631  IsHoliday_False    C   39910    22          0.00   Test   True  False
# 536632  IsHoliday_False    C   39910    22          0.00   Test   True  False
# 536633  IsHoliday_False    B  118221    39          0.00   Test   True  False
#
#           mk3    mk4    mk5   mcpi  mUemp   DateType  Month     BlackFriday  \
# 0       False  False  False   True   True 2010-02-05      2  BlackFriday_No
# 1       False  False  False   True   True 2010-02-19      2  BlackFriday_No
# 2       False  False  False   True   True 2010-02-26      2  BlackFriday_No
# 3       False  False  False   True   True 2011-02-04      2  BlackFriday_No
# 4       False  False  False   True   True 2011-02-18      2  BlackFriday_No
# ...       ...    ...    ...    ...    ...        ...    ...             ...
# 536629   True   True   True  False  False 2013-06-14      6  BlackFriday_No
# 536630   True  False   True  False  False 2013-07-12      7  BlackFriday_No
# 536631   True  False   True  False  False 2013-07-19      7  BlackFriday_No
# 536632   True  False   True  False  False 2013-07-26      7  BlackFriday_No
# 536633   True   True   True   True   True 2013-04-26      4  BlackFriday_No
#
#            PreChristmasDay  MedianSales PriorWeekDate  PriorWeek  \
# 0       PreChristmasDay_No     23510.49    2010-01-29        0.0
# 1       PreChristmasDay_No     23510.49    2010-02-12        1.0
# 2       PreChristmasDay_No     23510.49    2010-02-19        1.0
# 3       PreChristmasDay_No     23510.49    2011-01-28        1.0
# 4       PreChristmasDay_No     23510.49    2011-02-11        1.0
# ...                    ...          ...           ...        ...
# 536629  PreChristmasDay_No      7563.04    2013-06-07        0.0
# 536630  PreChristmasDay_No      7563.04    2013-07-05        0.0
# 536631  PreChristmasDay_No      7563.04    2013-07-12        0.0
# 536632  PreChristmasDay_No      7563.04    2013-07-19        0.0
# 536633  PreChristmasDay_No      7563.04    2013-04-19        0.0
#
#         PriorWeekSale  IsHoliday_False  IsHoliday_True  PreChristmasDay_No  \
# 0            23510.49                1               0                   1
# 1            46039.49                1               0                   1
# 2            41595.55                1               0                   1
# 3            18461.18                1               0                   1
# 4            37887.17                1               0                   1
# ...               ...              ...             ...                 ...
# 536629        7563.04                1               0                   1
# 536630        7563.04                1               0                   1
# 536631        7563.04                1               0                   1
# 536632        7563.04                1               0                   1
# 536633        7563.04                1               0                   1
#
#         PreChristmasDay_Yes  BlackFriday_No  BlackFriday_Yes  SalesDifference  \
# 0                         0               1                0             0.00
# 1                         0               1                0        -22529.00
# 2                         0               1                0        -18085.06
# 3                         0               1                0          5049.31
# 4                         0               1                0        -14376.68
# ...                     ...             ...              ...              ...
# 536629                    0               1                0             0.00
# 536630                    0               1                0             0.00
# 536631                    0               1                0             0.00
# 536632                    0               1                0             0.00
# 536633                    0               1                0             0.00
#
#         Difference
# 0         -1414.01
# 1        -18085.06
# 2          4106.95
# 3          1844.73
# 4        -23335.38
# ...            ...
# 536629     7563.04
# 536630     7563.04
# 536631     7563.04
# 536632     7563.04
# 536633     7563.04
#
# [536634 rows x 40 columns]

# %%
corr = dataframe.corr()

plt.subplots(figsize=(11, 10))

sns.set(style='white')

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, square=True, center=0, linewidths=0.5,vmax=0.3,cbar_kws={'shrink': 0.5} )
# Out:
# <AxesSubplot:>

# %% [markdown]
# We are done with our data feature engineering and series manupilation.
# Now, it's time to reep the fruits of our data manipulation labors and feed it to AI model.

# %%
# we will choose only essential features to train the model as selector

choosen = [
    'CPI','Fuel_Price','MarkDown1', 'MarkDown2','MarkDown3', 'MarkDown4', 'MarkDown5', 'Size','Temperature',
    'Unemployment', 'mk1', 'mk2', 'mk3', 'mk4', 'mk5', 'mcpi','mUemp', 'IsHoliday_False', 'IsHoliday_True',
    'PreChristmasDay_No', 'PreChristmasDay_Yes','BlackFriday_No', 'BlackFriday_Yes',    
    'PriorWeekSale','SalesDifference','PriorWeek'
]

display(dataframe[choosen].describe())
display(dataframe[choosen].head())
# Out:
#                  CPI     Fuel_Price      MarkDown1      MarkDown2  \
# count  536634.000000  536634.000000  536634.000000  536634.000000
# mean      159.852499       3.408310    3681.287709    1292.745138
# std        58.383773       0.430861    7593.883000    5714.136207
# min         0.000000       2.472000   -2781.450000    -265.760000
# 25%       131.126667       3.041000       0.000000       0.000000
# 50%       140.439786       3.523000       0.000000       0.000000
# 75%       212.303441       3.744000    5046.740000     118.730000
# max       228.976456       4.468000  103184.980000  104519.540000
#
#            MarkDown3      MarkDown4      MarkDown5           Size  \
# count  536634.000000  536634.000000  536634.000000  536634.000000
# mean      838.971725    1489.918846    2147.337557  136678.550960
# std      7860.456173    4865.593575    9789.902903   61007.711799
# min      -179.260000       0.000000    -185.170000   34875.000000
# 25%         0.000000       0.000000       0.000000   93638.000000
# 50%         0.000000       0.000000       0.000000  140167.000000
# 75%        29.140000     906.450000    2852.190000  202505.000000
# max    149483.310000   67474.850000  771448.100000  219622.000000
#
#          Temperature   Unemployment  IsHoliday_False  IsHoliday_True  \
# count  536634.000000  536634.000000    536634.000000   536634.000000
# mean       58.771762       7.237779         0.928091        0.071909
# std        18.678716       2.691035         0.258338        0.258338
# min        -7.290000       0.000000         0.000000        0.000000
# 25%        45.250000       6.334000         1.000000        0.000000
# 50%        60.060000       7.567000         1.000000        0.000000
# 75%        73.230000       8.512000         1.000000        0.000000
# max       101.950000      14.313000         1.000000        1.000000
#
#        PreChristmasDay_No  PreChristmasDay_Yes  BlackFriday_No  \
# count       536634.000000        536634.000000   536634.000000
# mean             0.988851             0.011149        0.988896
# std              0.104999             0.104999        0.104791
# min              0.000000             0.000000        0.000000
# 25%              1.000000             0.000000        1.000000
# 50%              1.000000             0.000000        1.000000
# 75%              1.000000             0.000000        1.000000
# max              1.000000             1.000000        1.000000
#
#        BlackFriday_Yes  PriorWeekSale  SalesDifference      PriorWeek
# count    536634.000000  536634.000000    536634.000000  536634.000000
# mean          0.011104   15969.738804      -195.362035       0.773412
# std           0.104791   22689.394444      6003.550792       0.418624
# min           0.000000   -1750.000000   -540263.085000       0.000000
# 25%           0.000000    2102.872500      -302.140000       1.000000
# 50%           0.000000    7608.320000         0.000000       1.000000
# 75%           0.000000   20182.661250       279.820000       1.000000
# max           1.000000  693099.360000    579251.325000       1.000000
#           CPI  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0  211.096358       2.572        0.0        0.0        0.0        0.0
# 1  211.289143       2.514        0.0        0.0        0.0        0.0
# 2  211.319643       2.561        0.0        0.0        0.0        0.0
# 3  212.566881       2.989        0.0        0.0        0.0        0.0
# 4  213.247885       3.045        0.0        0.0        0.0        0.0
#
#    MarkDown5    Size  Temperature  Unemployment    mk1    mk2    mk3    mk4  \
# 0        0.0  151315        42.31         8.106  False  False  False  False
# 1        0.0  151315        39.93         8.106  False  False  False  False
# 2        0.0  151315        46.63         8.106  False  False  False  False
# 3        0.0  151315        42.27         7.742  False  False  False  False
# 4        0.0  151315        57.36         7.742  False  False  False  False
#
#      mk5  mcpi  mUemp  IsHoliday_False  IsHoliday_True  PreChristmasDay_No  \
# 0  False  True   True                1               0                   1
# 1  False  True   True                1               0                   1
# 2  False  True   True                1               0                   1
# 3  False  True   True                1               0                   1
# 4  False  True   True                1               0                   1
#
#    PreChristmasDay_Yes  BlackFriday_No  BlackFriday_Yes  PriorWeekSale  \
# 0                    0               1                0       23510.49
# 1                    0               1                0       46039.49
# 2                    0               1                0       41595.55
# 3                    0               1                0       18461.18
# 4                    0               1                0       37887.17
#
#    SalesDifference  PriorWeek
# 0             0.00        0.0
# 1        -22529.00        1.0
# 2        -18085.06        1.0
# 3          5049.31        1.0
# 4        -14376.68        1.0

# %%
# Lets split the Traing and Testing sets

train = dataframe.loc[dataframe['Split'] == 'Train']
test = dataframe.loc[dataframe['Split'] == 'Test']

# %%
# Further, we will split our training set into evaluation set and train-set to keep performance in the view


from sklearn.model_selection import train_test_split


np.random.seed(101)     # Keeping the data in a seed 

X_train, X_eval, y_train, y_eval = train_test_split(train[choosen], train['Difference'], test_size=0.2,
                                                    random_state=101)

# Save computing power by changing the bit into 32.

X_train = X_train.astype('float32')
X_eval = X_eval.astype('float32')

# %%
print(X_eval.shape)
print(y_eval.shape)

# Good to go, for each training set there is a label.
# Out:
# (84314, 26)
# (84314,)

# %%
# Our data is all set now, lets build a deep-neural network with two hidde layers the Input Tensor will be a
# a simple train test Input.

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


neural = False

if neural:
    # Sequential model
    model = keras.Sequential([
        keras.Input(shape=(X_train.shape[0], X_train.shape[1])),
        layers.Dense(32, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
        layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
        layers.Dense(1, activation='linear')
    ])
    
    model.compile(
        optimizer = keras.optimizers.Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08),
        loss = keras.losses.MeanAbsoluteError(),
        metrics= ['accuracy']
    )
    
    trained_model = model.fit(X_train, y_train, epochs=500, batch_size=2048, verbose=0)
    model.evaluate(x=X_eval, y=y_eval)

# %% [markdown]
# As we can see:
#    10 epochs 18% accuracy,
#    100 epochs 38% accuracy
#    500 epochs 44%  accuracy

# %%
    #plt.plot(trained_model.history['loss'], label='Adam Regularized')
    #plt.xlabel('Epochs')
    #plt.ylabel('loss')
    #plt.legend()
    #plt.show()
    #y_pred_neural = model.predict(X_eval)

# %%
# Lets build another model using Random-Forest-Regressor alog.
# Why Random Forest?
# As Random forest is one of the best model to predict missing values given the dataset, efficent accuracy with
# low training time, also prevent from overfitting.

from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
                    n_jobs=2,
                    n_estimators=80,
                    criterion='mse',
                    max_depth=None,
                    min_samples_split=2,
                    min_samples_leaf=0.5,
                    min_weight_fraction_leaf=0.0,
                    max_features='auto',
                    max_leaf_nodes=None,
                    min_impurity_decrease=0.0,
                    min_impurity_split=None,
                    bootstrap=True,
                    oob_score=False,
                    random_state=None,
                    verbose=0,
                    warm_start=False
                    )

# %%
rf_model.fit(X_train, y_train.ravel())  # Return a contiguous flattened array.
# Out:
# RandomForestRegressor(min_samples_leaf=0.5, n_estimators=80, n_jobs=1)

# %%
pred_rf_model = rf_model.predict(X_eval)

# %%
y_eval = y_eval.to_frame()

# %%
# Transform forest predictions to observe direction of change

TrueDirection1 = binary(y_eval.values)
PredDirection = binary(pred_rf_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f84645b59041> in <module>
#       1 # Transform forest predictions to observe direction of change
#       2
# ----> 3 TrueDirection1 = binary(y_eval.values)
#
# NameError: name 'binary' is not defined
